# %% [markdown]
# # New section

# %% [markdown]
# # New section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pymongo

# %%
pip install dnspython==2.0.0

# %%
myclient = pymongo.MongoClient("mongodb+srv://test123:test123@cluster0.gir0v.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
db=myclient.get_database("students_db")

# %%
records=db.students_record

# %% [markdown]
# **Count Documents**

# %%
records.count_documents({})
# Out:
# 1

# %% [markdown]
# **Create New Document**

# %%
new_student={
    "name":"Yash",
    "roll_no":13,
    "branch":"AI"
}

# %%
records.insert_one(new_student)

# %%
new_students=[
              {"name":"Yashwant",
    "roll_no":14,
    "branch":"AI"
                  
              },
              {
                  "name":"Yashika",
    "roll_no":15,
    "branch":"AI"
              }
]

# %%
records.insert_many(new_students)

# %% [markdown]
# **Find Documents**

# %%
list(records.find())
# Out:
# [{'_id': ObjectId('60fe6efc49fb1e1c6ec910ef'),
#   'branch': 'cs',
#   'name': 'Divitya',
#   'roll_no': 12},
#  {'_id': ObjectId('60fe84a9502eac3432ef2641'),
#   'branch': 'AI',
#   'name': 'Yash',
#   'roll_no': 13},
#  {'_id': ObjectId('60fe8540502eac3432ef2642'),
#   'branch': 'AI',
#   'name': 'Yash',
#   'roll_no': 13},
#  {'_id': ObjectId('60fe8540502eac3432ef2643'),
#   'branch': 'AI',
#   'name': 'Yash',
#   'roll_no': 13},
#  {'_id': ObjectId('60fe856a502eac3432ef2644'),
#   'branch': 'AI',
#   'name': 'Yashwant',
#   'roll_no': 14},
#  {'_id': ObjectId('60fe856a502eac3432ef2645'),
#   'branch': 'AI',
#   'name': 'Yashika',
#   'roll_no': 15}]

# %%
records.find_one({"roll_no":15})
# Out:
# {'_id': ObjectId('60fe856a502eac3432ef2645'),
#  'branch': 'AI',
#  'name': 'Yashika',
#  'roll_no': 15}

# %% [markdown]
# **Update Document**

# %%
student_updates={
    "name":"Divya"
}

# %%
records_update_one({"rollno":15},{$set})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d92b55396895> in <module>()
# ----> 1 records_update_one({"rollno":15},{"$set":student_updates})
#
# NameError: name 'records_update_one' is not defined
